# %% [markdown]
# # Content-Based Course Recommendation
#
# This notebook builds a recommender using TF-IDF on course titles and cosine similarity.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# Load dataset
courses = pd.read_csv("../data/udemy_course_data.csv")
courses["course_title"] = courses["course_title"].str.lower()

# TF-IDF
tfidf = TfidfVectorizer(stop_words="english")
tfidf_matrix = tfidf.fit_transform(courses["course_title"])
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

def recommend_course(idx, top_n=5):
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    return [courses.iloc[i[0]]["course_title"] for i in sim_scores[1:top_n+1]]

# Example output
recommend_course(10)
# Out:
# ["python for beginners", "advanced python programming", "data science with python"]
